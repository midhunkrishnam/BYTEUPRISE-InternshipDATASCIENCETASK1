# %% [markdown]
# <a href="https://colab.research.google.com/github/midhunkrishnam/byte-uprise-Internship/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/svm_data.csv")
df
# Out:
#           x1        x2  y
# 0   0.486861  0.163756  0
# 1   0.590718  0.429319  0
# 2   0.537981  0.082374  0
# 3   0.184411  0.717404  1
# 4   0.825697  0.414670  1
# ..       ...       ... ..
# 95  0.497268  0.136202  0
# 96  0.819918  0.334533  1
# 97  0.328380  0.980288  1
# 98  0.052043  0.489631  1
# 99  0.886068  0.930075  0
#
# [100 rows x 3 columns]

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#          x1        x2  y
# 0  0.486861  0.163756  0
# 1  0.590718  0.429319  0
# 2  0.537981  0.082374  0
# 3  0.184411  0.717404  1
# 4  0.825697  0.414670  1

# %%
df.tail()
# Out:
#           x1        x2  y
# 95  0.497268  0.136202  0
# 96  0.819918  0.334533  1
# 97  0.328380  0.980288  1
# 98  0.052043  0.489631  1
# 99  0.886068  0.930075  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      100 non-null    float64
#  1   x2      100 non-null    float64
#  2   y       100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.corr()
# Out:
#           x1        x2         y
# x1  1.000000  0.038179  0.002003
# x2  0.038179  1.000000  0.180743
# y   0.002003  0.180743  1.000000

# %%
df.dtypes
# Out:
# x1    float64
# x2    float64
# y       int64
# dtype: object

# %%
df.describe()
# Out:
#                x1          x2       y
# count  100.000000  100.000000  100.00
# mean     0.503413    0.534955    0.45
# std      0.281093    0.284029    0.50
# min      0.009503    0.012806    0.00
# 25%      0.277163    0.329032    0.00
# 50%      0.535608    0.544606    0.00
# 75%      0.716597    0.781614    1.00
# max      0.985195    0.998253    1.00

# %%
df.isnull().sum()
# Out:
# x1    0
# x2    0
# y     0
# dtype: int64

# %%
plt.bar(df['y'].value_counts().index, df['y'].value_counts().values, color=['red', 'blue'])
plt.xlabel('Class',color='green')
plt.ylabel('Count',color='green')
plt.title('Distribution of Target Variable ',color='green')
plt.xticks([0, 1])
plt.show()
